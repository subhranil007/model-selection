# %% [markdown]
# [Dataset](https://drive.google.com/drive/folders/1OC3pP97DG4u067o8RrLUBdajZE8HL7zP?usp=sharing)

# %% [markdown]
# # 1. Principles of Model Selection

# %% [markdown]
# ## 1.1. Introduction to Model Selection

# %% [markdown]
# - **Choice of Model Selection:**
#   - Trial and error
#   - Domain knowledge
#     - Model selection
#     - Model evaluation
#     - Model comparison

# %% [markdown]
# - **Occam's razor:**
#   - Making the model as simple as possible
#   - When in dilemma, choose the simpler model
#   - Definition of simplicity varies with respect to the type of model under consideration.
#   - Simplicity in case of a tree model would mean a reduced depth or size but when it comes to a linear model, it can be expressed in terms of the number of attributes required to represent a model.

# %% [markdown]
# ## 1.2. Simplicity vs Complexity

# %% [markdown]
# - There are some practical issues that you need to deal with when you make a choice of the models to be considered before going into solving the business problem. Some of these include:
#   - Type of data - numerical, categorical, strings, dates etc.
#   - Data quality - missing values, noisy data
#   - Dimensionality of data - high or low
#
# - A model should never be evaluated on the data it has been trained on

# %% [markdown]
# - **Complexity of a model:**
#   1. Simpler models are usually more 'generic'.
#   2. Simpler models require fewer training samples
#   3. Simpler models are more robust
#   4. Simpler models make more errors in the training

# %% [markdown]
# ## 1.3. Overfitting and Underfitting

# %% [markdown]
# - **Overfitting:**
#
#   - Overfitting is a phenomenon where a model becomes too specific to the data it is trained on and fails to generalise to other unseen data points in the larger domain. A model that has become too specific to a training dataset has actually ‘learnt’ not just the hidden patterns in the data but also the noise and the inconsistencies in the data. In a typical case of overfitting, the model performs very well on the training data but fails miserably on the test data.
#
#   - Luckily, there are quite a few techniques you can use to tackle overfitting. These techniques include:
#
#    1. Increase the training data
#    2. Reduce the number of insignificant features by feature selection
#    3. Apply cross-validation schemes to train multiple models on the same dataset
#    4. Early stopping to prevent the model from memorising the dataset
#    5. Apply regularisation techniques to reduce model complexity. You can understand more about regularisation from the additional resources available in the last session of this module.
#
# - **Underfitting:**
#   - Underfitting is a phenomenon where a model is too naive to capture the underlying patterns/trends of the data. Such a model does not learn enough from the training data and hence fails to generalise on new data which leads to unreliable results. Underfitting usually happens when you have less training data to build a sufficiently complex model. In a typical case of underfitting, a model fails to perform well on the training data as well as the test data.
#
#   - Like overfitting, you have set techniques to tackle underfitting as well; these are:
#
#     1. Increase the training data
#     2. Increase the number of features by feature engineering
#     3. Increase the model complexity by adding more parameters
#     4. Increase the training time until the objective function is minimised

# %% [markdown]
# ## 1.4. Bias-Variance Tradeoff

# %% [markdown]
# - **Variance:**
#
#   - How sensitive is the model to input data
#   - The ‘variance’ of a model is the variance in its output on some test data with respect to the changes in the training data. In other words, variance here refers to the degree of changes in the model itself with respect to changes in training data.
#
# - **Bias:**
#
#   - How much error the model likely to make in test data
#   - Bias quantifies how accurate the model is likely to be on future (test) data. Extremely simple models are likely to fail in predicting complex real-world phenomena. Simplicity has its own disadvantages.
#
# - **Bias and Variance:**
#
#   - A model which suffers from underfitting is usually a high bias and low variance model whereas a model which suffers from overfitting is usually a low bias and high variance model due to increased complexity.
#   - In an ideal case, we want to reduce both the bias and the variance, because the expected total error of a model is the sum of the errors in bias and the variance, as shown in the figure below.
# ![](https://cdn.upgrad.com/UpGrad/temp/e37d2d0d-cad1-454c-8678-a471eac0b404/Bias_variance.png)

# %% [markdown]
# ## 1.5. Model Evaluation - Classification Metrics

# %% [markdown]
# 1. **Accuracy,  Misclassification error:**
#
#   Ex. We have 99 class 0 example and 1 Class 1 example. I also have a model that always outputs class label as 0 for whatever test point comes to it. The model will have 99% accuracy, even if the model is inaccurate. Accuracy only works when we have balaced dataset.

# %% [markdown]
# 2. **Confusion Matrix:**
#
#   We have a model that scores True Class 1 data as 0.3 and True Class 0 data as 0.1. If the threshold as 0.2, it will be a perfect classifier. Confusion matrix uses a haed threshold of 0.5.

# %% [markdown]
# 3. **Precision, Recall, F1-Score:**
#
#   Precision, Recall, F1-Score also depends on the hard threshold.

# %% [markdown]
# 4. **ROC Curve:**
#
#   A curve between True Positive Rate (TPR), False Positive Rate (FPR). ROC curve takes into account all the threshold value.

# %% [markdown]
# - In the previous example, we had a model that scores True Class 1 data as 0.3 and True Class 0 data as 0.1. If the threshold as 0.2, it will be a perfect classifier. In real life need the perfect threshold to reach final classification or ROC curve. i.e., we have to find such a threshold that maximizes (TPR - FPR)

# %% [markdown]
# ## 1.6. Model Evaluation - Regression Metrics

# %% [markdown]
# 1. **Root Mean Square Error(RMSE):**
#
#   RMSE is the most commonly used regression metrics. It represents the sample standard deviation between the actual and the predicted values. It is calculated using the formula:
#
# $$ RMSE=√1n∑^n_i=1(yi−ŷ)^2 $$
#
#   Where,
#
#   $$ yi\space and\space ŷ\space are\space the\space actual\space and\space predicted\space values\space respectively\space and\space n\space is\space the\space number\space of\space observations $$

# %% [markdown]
# 2. **Mean Absolute Error(MAE):**
#
#   MAE is the average of the absolute difference between the actual and the predicted values. It is calculated using the formula:
#
#   $$ MAE=1n∑ni=1∣yi−ŷ∣ $$

# %% [markdown]
# 3. **Mean Absolute Percentage Error(MAPE):**
#
#   MAPE is the percentage equivalent of Mean Absolute Error. It can be defined as the percentage ratio of the residue over the actual value. It is in the form of percentage which makes it easier for people to comprehend, hence it is also a commonly used metric. It is calculated using the formula:
#
# $$ MAPE=\frac{100}{n}∑_n^i \frac{ ∣y_i−ŷ ∣}{y_i} $$

# %% [markdown]
# 4. **R-Squared (R²):**
#
#   R², also known as the coefficient of determination, measures the proportion of variation in the dependent variable that is explained by all the independent variables in the model. Higher the value of R² better is the model. It is calculated using the formula:
#   $$ R^2 = 1 - \frac{ \frac{1}{n} ∑^n_i(yi−ŷ)^2 }{ \frac{1}{n} ∑^n_i(yi−ȳ)^2 } $$

# %% [markdown]
# 5. **Adjusted R-Squared:**
#
#   Adjusted R² is the modified version of R² and it adjusts for the number of independent variables in a model. It is a proportion of variation that is explained by the independent variables actually affecting the dependent variable. It is calculated using the formula:
#
# $$ R^2_{adj} = 1 - \frac{(1-R^2)(n-k)}{n-k-1} $$

# %% [markdown]
#   Where n is the total number of observations and k is the number of independent variables in the model.
#
#   The value of adjusted R² is always less than or equal to the R² value. R² keeps increasing on the addition of independent variables into the model irrespective of how well they are correlated with the dependent variable whereas adjusted R² penalises the model for the inclusion of insignificant variables which do not help in improving the existing model. Hence, it is recommended to assess the performance of a multiple linear regression model by using only adjusted R² instead of a R² value because it is quite misleading.

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ## 1.1. Introduction to Feature Engineering

# %% [markdown]
# - **Business Problem Solving Framework:**
#   1. Business Understanding
#   2. Data Understanding
#   3. Data Preparation
#   4. Data Modelling
#   5. Model Evaluation
#   6. Model Deployment

# %% [markdown]
# - **Definition of Feature Engineering:**
#
#   - Creating new features from the given dataset by utilising the domain knowledge to improve the machine learning algorithm's efficiency.
#   - Involves modifying, combining,  extracting or selecting features to train the algorithm.
#
# - **Motivation of Feature Engineering:**
#
#   - Represent the underlying structure of the data more accurately
#   - Prepare the dataset to be more compatible with the algorithm
#   - Extract useful information/features from the raw data and use it for model building process
#   - Create features which are prone to overfitting
#   - Build robust models with better predictive performances
#
# - Depending on the type of data that you have there can be several types of feature engineering techniques:
#
#   - Continous numeric features:
#
#     - Scalling - Standardization and Normalization
#     - Binning
#     - Transformations (Log, Power Transforms like Yeo-Johnson, Box cox):
#       - Log transformation is a technique used to transform highly skewed data to less skewed. It compresses the spread of the data on a higher scale, and hence, the shape of the data changes.
#       - Power transformation is a family of transformations, among which the Yeo Johnson and Box-Cox transformations are the most popular.
#       - In the Box-Cox transformation, the non-normal features are transformed into a normal distribution, which is an important assumption in many of the statistical techniques.
#     - Derived Features
#
#   - Categorical features:
#     - Dummy/One-Hot Encoding
#     - Label Encoding
#     - Mean Encoding: Mean/target encoding is the process in which the target variable is used to generate a new encoded feature. This is done by replacing a category with the mean value of the target variable corresponding to each occurrence of the same category.
#     - Clubbing Features:
#       - Based on frequency
#       - Based on target variable
#
#   - Time based features: Extract useful features based on time and temporal patterns in the data. This features can be based on:
#
#     - Monthly cyclicity
#     - Weekly patterns
#     - Patterns in hour of the day
#     - Holidays

# %% [markdown]
# ## 2.1. Feature Engineering Using Python

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %%
bank = pd.read_csv('bank.csv',sep = ';')

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
bank.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank2 = bank.copy()

# %%
#Let's do the mapping for yes responses to 1's and nos to 0's
bank2.y = bank2.y.map({'yes':1,'no':0})

# %%
bank2.y.value_counts(normalize=True)
# Out:
# 0    0.887346
# 1    0.112654
# Name: y, dtype: float64

# %% [markdown]
# **Test Train Split**

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(bank2, random_state=42)

# %%
df_train.shape, df_test.shape
# Out:
# ((30891, 21), (10297, 21))

# %% [markdown]
# ## 2.2. Handling Numeric Features

# %%
df_train.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  30891.000000  30891.000000  30891.000000  30891.000000  30891.000000
# mean      40.017287    257.551746      2.568839    963.029361      0.172348
# std       10.448075    259.371218      2.747802    185.544213      0.492298
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     43.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  \
# count  30891.000000    30891.000000   30891.000000  30891.000000
# mean       0.083264       93.577223     -40.506782      3.622596
# std        1.570746        0.579333       4.629842      1.734393
# ...

# %% [markdown]
# **`duration` feature:**

# %%
plt.boxplot(df_train.duration)
plt.show()

# %%
sns.distplot(df_train.duration)
plt.show()

# %% [markdown]
# **Applying a log transformation:**

# %%
df_train['dur_log'] = np.log1p(df_train.duration)

# %%
sns.distplot(df_train.dur_log)
plt.show()

# %% [markdown]
# **Applying PowerTransform:**

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt = PowerTransformer()

# %%
df_train['dur_trans'] = pt.fit_transform(df_train[['duration']])

# %%
sns.distplot(df_train.dur_trans)
plt.show()

# %% [markdown]
# **Feature scaling:**

# %%
df_train[['age', 'dur_log']].describe()
# Out:
#                 age       dur_log
# count  30891.000000  30891.000000
# mean      40.017287      5.170355
# std       10.448075      0.916576
# min       17.000000      0.000000
# 25%       32.000000      4.634729
# 50%       38.000000      5.192957
# 75%       47.000000      5.765191
# max       98.000000      8.500861

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df_train[['dur_log']] = scaler.fit_transform(df_train[['dur_log']])

# %%
df_train[['dur_log']].describe()
# Out:
#             dur_log
# count  30891.000000
# mean       0.608215
# std        0.107822
# min        0.000000
# 25%        0.545207
# 50%        0.610874
# 75%        0.678189
# max        1.000000

# %% [markdown]
# **```age``` variable:**

# %%
plt.hist(df_train.age, bins=20)
plt.show()

# %% [markdown]
# Create bins -
#
# - 25, 25-50, 50-75, >75

# %%
bin_manual = [0, 25, 50, 75, 100]
labs = ['<25', '25-50','50-75','above 75']

# %%
# ?pd.cut

# %%
df_train['age_bin'] = pd.cut(df_train.age, bins=bin_manual, labels=labs)

# %%
df_train[['age_bin','age']].head()
# Out:
#       age_bin  age
# 549     25-50   50
# 1974    25-50   26
# 20992   25-50   34
# 1730    25-50   30
# 26913   25-50   29

# %%
df_train.groupby('age_bin')['age'].agg(['max','min'])
# Out:
#           max  min
# age_bin
# <25        25   17
# 25-50      50   26
# 50-75      75   51
# above 75   98   76

# %% [markdown]
# **Quantile based binning**

# %%
labs = ['VL','L','M','H','VH']
quantiles = [0, 0.2, 0.4, 0.6, 0.8, 1]

# %%
df_train['age_bin'] = pd.qcut(df_train.age, quantiles, labs)

# %%
df_train.groupby('age_bin')['age'].agg(['min', 'max'])
# Out:
#          min  max
# age_bin
# VL        17   31
# L         32   35
# M         36   41
# H         42   49
# VH        50   98

# %%
df_train.age_bin.value_counts(normalize=True)
# Out:
# VL    0.227445
# M     0.206597
# VH    0.196336
# H     0.195202
# L     0.174420
# Name: age_bin, dtype: float64

# %% [markdown]
# ## 2.3. Handling Categorical Features

# %% [markdown]
# **Dummy encoding:**

# %%
df_train.head()
# Out:
#        age          job  marital          education  default  housing  \
# 549     50  blue-collar  married           basic.4y  unknown  unknown
# 1974    26  blue-collar   single        high.school       no       no
# 20992   34   technician  married        high.school       no      yes
# 1730    30  blue-collar   single           basic.9y       no      yes
# 26913   29       admin.   single  university.degree       no      yes
#
#           loan    contact month day_of_week  ...     poutcome  emp.var.rate  \
# 549    unknown  telephone   may         tue  ...  nonexistent           1.1
# 1974        no  telephone   may         fri  ...  nonexistent           1.1
# 20992       no   cellular   aug         thu  ...  nonexistent           1.4
# 1730        no  telephone   may         fri  ...  nonexistent           1.1
# 26913       no   cellular   nov         thu  ...  nonexistent          -0.1
#
#        cons.price.idx  cons.conf.idx euribor3m  nr.employed  y   dur_log  \
# ...

# %%
df_train.marital.value_counts(normalize=True)
# Out:
# married     0.602732
# single      0.283189
# divorced    0.112266
# unknown     0.001813
# Name: marital, dtype: float64

# %%
pd.get_dummies(df_train.marital, prefix='Mari', drop_first=True)
# Out:
#        Mari_married  Mari_single  Mari_unknown
# 549               1            0             0
# 1974              0            1             0
# 20992             1            0             0
# 1730              0            1             0
# 26913             0            1             0
# ...             ...          ...           ...
# 6265              1            0             0
# 11284             1            0             0
# 38158             1            0             0
# 860               1            0             0
# 15795             0            1             0
#
# [30891 rows x 3 columns]

# %%
pd.get_dummies(df_train, columns= ['marital'], prefix=['Mari'], drop_first=True)
# Out:
#        age          job            education  default  housing     loan  \
# 549     50  blue-collar             basic.4y  unknown  unknown  unknown
# 1974    26  blue-collar          high.school       no       no       no
# 20992   34   technician          high.school       no      yes       no
# 1730    30  blue-collar             basic.9y       no      yes       no
# 26913   29       admin.    university.degree       no      yes       no
# ...    ...          ...                  ...      ...      ...      ...
# 6265    58      retired  professional.course  unknown       no       no
# 11284   37   management    university.degree       no       no       no
# 38158   35       admin.          high.school       no      yes       no
# 860     40   management    university.degree       no      yes       no
# 15795   29       admin.    university.degree       no      yes       no
#
#          contact month day_of_week  duration  ...  cons.conf.idx  euribor3m  \
# ...

# %% [markdown]
# **Job column**

# %%
pd.get_dummies(df_train.job, prefix='job', drop_first=True)
# Out:
#        job_blue-collar  job_entrepreneur  job_housemaid  job_management  \
# 549                  1                 0              0               0
# 1974                 1                 0              0               0
# 20992                0                 0              0               0
# 1730                 1                 0              0               0
# 26913                0                 0              0               0
# ...                ...               ...            ...             ...
# 6265                 0                 0              0               0
# 11284                0                 0              0               1
# 38158                0                 0              0               0
# 860                  0                 0              0               1
# 15795                0                 0              0               0
#
#        job_retired  job_self-employed  job_services  job_student  \
# ...

# %% [markdown]
# **Label encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencoder = LabelEncoder()

# %%
df_train['job_le'] = lencoder.fit_transform(df_train.job)

# %%
df_train.groupby('job')['job_le'].agg(['min', 'max'])
# Out:
#                min  max
# job
# admin.           0    0
# blue-collar      1    1
# entrepreneur     2    2
# housemaid        3    3
# management       4    4
# retired          5    5
# self-employed    6    6
# services         7    7
# student          8    8
# technician       9    9
# unemployed      10   10
# unknown         11   11

# %% [markdown]
# **Mean encoding**

# %%
map_mean = df_train.groupby('job')['y'].mean()
map_mean
# Out:
# job
# admin.           0.131931
# blue-collar      0.069964
# entrepreneur     0.082791
# housemaid        0.088308
# management       0.109829
# retired          0.245106
# self-employed    0.099166
# services         0.083832
# student          0.307806
# technician       0.110643
# unemployed       0.144966
# unknown          0.100000
# Name: y, dtype: float64

# %%
df_train['job_mean_encode'] = df_train.job.map(map_mean)

# %%
df_train.groupby('job')['job_mean_encode'].agg(['min', 'max'])
# Out:
#                     min       max
# job
# admin.         0.131931  0.131931
# blue-collar    0.069964  0.069964
# entrepreneur   0.082791  0.082791
# housemaid      0.088308  0.088308
# management     0.109829  0.109829
# retired        0.245106  0.245106
# self-employed  0.099166  0.099166
# services       0.083832  0.083832
# student        0.307806  0.307806
# technician     0.110643  0.110643
# unemployed     0.144966  0.144966
# unknown        0.100000  0.100000

# %% [markdown]
# **Clubbing categories**

# %% [markdown]
# **Top N based on frequency**

# %%
df_train.job.value_counts(normalize=True)
# Out:
# admin.           0.253957
# blue-collar      0.225794
# technician       0.161503
# services         0.097310
# management       0.070150
# retired          0.041339
# self-employed    0.034929
# entrepreneur     0.034800
# housemaid        0.026027
# unemployed       0.024117
# student          0.021981
# unknown          0.008093
# Name: job, dtype: float64

# %%
job_freqs = df_train.job.value_counts(normalize=True)

# %%
job_freqs.cumsum()
# Out:
# admin.           0.253957
# blue-collar      0.479751
# technician       0.641255
# services         0.738565
# management       0.808715
# retired          0.850053
# self-employed    0.884983
# entrepreneur     0.919782
# housemaid        0.945809
# unemployed       0.969927
# student          0.991907
# unknown          1.000000
# Name: job, dtype: float64

# %%
sns.lineplot(job_freqs.cumsum())
sns.barplot(df_train.job.value_counts(normalize=True))
plt.xticks(rotation = 90)
plt.show()

# %%
top_jobs = job_freqs.cumsum()[:4].index
top_jobs
# Out:
# Index(['admin.', 'blue-collar', 'technician', 'services'], dtype='object')

# %%
 df_train['job_mod_topn'] = np.where(df_train.job.isin(top_jobs), df_train.job, 'OTH')

# %%
df_train.groupby(['job_mod_topn','job']).size()
# Out:
# job_mod_topn  job
# OTH           entrepreneur     1075
#               housemaid         804
#               management       2167
#               retired          1277
#               self-employed    1079
#               student           679
#               unemployed        745
#               unknown           250
# admin.        admin.           7845
# blue-collar   blue-collar      6975
# services      services         3006
# technician    technician       4989
# dtype: int64

# %% [markdown]
# **Clubbing categories - based on Target**

# %%
df_train.groupby('job')['y'].mean().sort_values().plot.barh()
plt.show()

# %%
def club_on_y(val):
    if val in ['student','retired']:
        return 'a_high'
    elif val in ['services', 'entrepreneur','blue-collar']:
        return 'c_low'
    else:
        return 'b_med'

# %%
df_train['job_mod_tgt'] = df_train.job.apply(club_on_y)

# %%
df_train.groupby(['job_mod_tgt','job']).size()
# Out:
# job_mod_tgt  job
# a_high       retired          1277
#              student           679
# b_med        admin.           7845
#              housemaid         804
#              management       2167
#              self-employed    1079
#              technician       4989
#              unemployed        745
#              unknown           250
# c_low        blue-collar      6975
#              entrepreneur     1075
#              services         3006
# dtype: int64

# %% [markdown]
# ## 2.4. Handling Time-Based Features

# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %%
raw0 = pd.read_csv('london_merged.csv')

# %%
raw0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
raw0.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
type(raw0.timestamp[0])
# Out:
# str

# %%
raw0.timestamp.apply(type).value_counts()
# Out:
# <class 'str'>    17414
# Name: timestamp, dtype: int64

# %% [markdown]
# **Convert timestamp to a datetime value**

# %%
bike1 = raw0.copy()

# %%
pd.to_datetime(bike1.timestamp)
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
bike1.timestamp = pd.to_datetime(bike1.timestamp)

# %%
bike1.timestamp.apply(type).value_counts()
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>    17414
# Name: timestamp, dtype: int64

# %%
bike1.timestamp.describe()
# Out:
# count                   17414
# unique                  17414
# top       2015-01-04 00:00:00
# freq                        1
# first     2015-01-04 00:00:00
# last      2017-01-03 23:00:00
# Name: timestamp, dtype: object

# %% [markdown]
# **Extract dates from the timestamps**

# %%
bike1['date'] = bike1.timestamp.dt.date

# %%
bike1.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season        date
# 0         0.0         1.0     3.0  2015-01-04
# 1         0.0         1.0     3.0  2015-01-04
# 2         0.0         1.0     3.0  2015-01-04
# 3         0.0         1.0     3.0  2015-01-04
# 4         0.0         1.0     3.0  2015-01-04

# %%
bike1.tail()
# Out:
#                 timestamp   cnt   t1   t2   hum  wind_speed  weather_code  \
# 17409 2017-01-03 19:00:00  1042  5.0  1.0  81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0  81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5  78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5  76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0  76.0        22.0           2.0
#
#        is_holiday  is_weekend  season        date
# 17409         0.0         0.0     3.0  2017-01-03
# 17410         0.0         0.0     3.0  2017-01-03
# 17411         0.0         0.0     3.0  2017-01-03
# 17412         0.0         0.0     3.0  2017-01-03
# 17413         0.0         0.0     3.0  2017-01-03

# %%
bike1.groupby('date')['cnt'].sum().plot(figsize=[11,5])
plt.show()

# %% [markdown]
# **Create a month column**

# %%
bike1['monthnum'] = bike1.timestamp.dt.month

# %%
bike1.groupby(['monthnum','date'])['cnt'].sum().groupby(['monthnum']).mean().plot()
plt.show()

# %%
bike1.season.value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
bike1.groupby(['season','monthnum']).size()
# Out:
# season  monthnum
# 0.0     3           1468
#         4           1438
#         5           1488
# 1.0     6           1422
#         7           1481
#         8           1484
# 2.0     9           1394
#         10          1479
#         11          1430
# 3.0     1           1487
#         2           1359
#         12          1484
# dtype: int64

# %% [markdown]
# 0: Spring
# 1: Summer
# 2: Fall
# 3: Winter

# %% [markdown]
# **Assessing the patterns in the week**

# %%
# ?bike1.timestamp.dt.dayofweek

# %%
bike1['dayinweek'] = bike1.timestamp.dt.dayofweek

# %%
bike1.groupby(['dayinweek','date'])['cnt'].sum().groupby(['dayinweek']).mean().plot()
plt.show()

# %%
bike1['flag_weekend'] = np.where(bike1.dayinweek.isin([5,6]),1,0)

# %%
bike1.groupby(['is_weekend', 'flag_weekend']).size()
# Out:
# is_weekend  flag_weekend
# 0.0         0               12444
# 1.0         1                4970
# dtype: int64

# %% [markdown]
# **Analyze rides by hour of the day**

# %%
bike1['hourinday'] = bike1.timestamp.dt.hour

# %%
bike1.head()
# Out:
#             timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season        date  monthnum  dayinweek  \
# 0         0.0         1.0     3.0  2015-01-04         1          6
# 1         0.0         1.0     3.0  2015-01-04         1          6
# 2         0.0         1.0     3.0  2015-01-04         1          6
# 3         0.0         1.0     3.0  2015-01-04         1          6
# 4         0.0         1.0     3.0  2015-01-04         1          6
#
#    flag_weekend  hourinday
# 0             1          0
# 1             1          1
# 2             1          2
# ...

# %%
bike1.groupby('hourinday')['cnt'].mean().plot(figsize=[10,5])
plt.show()

# %%
peak_hours = [7,8,9,16,17,18]

# %%
bike1['flag_peakhr'] = np.where(bike1.hourinday.isin(peak_hours), 1, 0)

# %% [markdown]
# **Holidays vs. other days**

# %%
bike1.groupby(['is_holiday','date'])['cnt'].sum().groupby(['is_holiday']).mean().plot.bar()
plt.show()
